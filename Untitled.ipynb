# %%
import pandas as pd
# !$pwd

# %%
# Out:
# /bin/sh: ${pwd$HOME}: bad substitution

# %%
path = "src/data_processing/instance.sensor_df.csv"

df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  TimeStamp  GnDe;0,0102;m/s2  GnNDe;0,0102;m/s2  \
# 0           0   0.000000       1234.790578        1210.111730
# 1           1   0.000039       1237.860287        1192.864811
# 2           2   0.000078       1221.784704        1234.750187
# 3           3   0.000117       1221.421186        1215.887631
# 4           4   0.000156       1225.743013        1242.262896
#
#    Speed Sensor;1;V  MnBrg;0,0102;m/s2  GbxRotBrg;0,0102;m/s2  LssShf;1;V  \
# 0           0.00618        1095.361149            1075.327256   -0.004532
# 1           0.00618        1095.320758            1076.054293   -0.003708
# 2           0.00618        1095.320758            1075.286865   -0.003708
# 3           0.00618        1095.401540            1075.004129   -0.004120
# 4           0.00618        1095.361149            1075.165692   -0.004120
#
#    Gbx1Ps;0,0102;m/s2  GbxHssFr;0,0102;m/s2  GbxHssRr;0,0102;m/s2  \
# 0         1072.701847           1208.455703           1189.875883
# ...
