# %% [markdown]
# <img src="../../images/wt4.png" align="right" width="70"/>
#
#   #     Notebook for early bearing fault detection for WT01

# %% [markdown]
# ## Table of contents
# 1. Raw signal
# 2. Resampled signal
# 3. Filtered signal with optimal bandpass based on SK
# 4. Demodulasation using EEMD signals
# 5. Selecting IMF: Correlation coefficient
# 6. Envelope spectral analyis
# 7. Frequency study

# %%
# %load_ext autoreload

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sys, os,os.path
import matplotlib.pyplot as plt

ROOT_PATH = os.path.abspath("..").split("data_processing")[0]
module_paths = []
module_paths.append(os.path.abspath(os.path.join(ROOT_PATH+"/data_processing/")))
module_paths.append(os.path.abspath(os.path.join(ROOT_PATH+"/hybrid_analysis_process_functions/")))
module_paths.append(os.path.abspath(os.path.join(ROOT_PATH+"/utils/")))
for module_path in module_paths:
    if module_path not in sys.path:
        print("appended")
        sys.path.append(module_path)
import functions as f
# %autoreload
import wt_data, ff_transform, explore_fft_time_data, envelope, build_dataset, load_raw_signals, envelope, envelope_emd
import resample_signals, filter_signals, plotting_methods
# Out:
# appended
# appended
# appended
# ROOT /Users/mortenolsenosvik/Documents/NTNU/Master/master-thesis/src
# /Users/mortenolsenosvik/Documents/NTNU/Master/master-thesis/src
# ROOT /Users/mortenolsenosvik/Documents/NTNU/Master/master-thesis/src
# ROOT /Users/mortenolsenosvik/Documents/NTNU/Master/master-thesis/src
# ROOT /Users/mortenolsenosvik/Documents/NTNU/Master/master-thesis/src

# %% [markdown]
# ## 1. Raw signal

# %%
vib_signal, times, op_data_intervals, peak_array = load_raw_signals.load_raw('gearbox','wt01')
avg_rpm = np.asarray(op_data_intervals['AvgSpeed'])
avg_power = np.asarray(op_data_intervals['AvgPower'])
# Out:
# File exist

# %%
envelope.plot_vib_consecutive(vib_signal)
# Out:
# 5
# 107216896

# %%
i=67
plotting_methods.plot_signal(times[i], vib_signal[i], peak_array=peak_array[i], x_min=-0.01, x_max=0.3, name='Original')

# %%
low_cut = 2000
filtered_raw_vib = []
vib_signal_size = len(vib_signal)

for i, vib_sig in enumerate(vib_signal):
    flitered_vib_sig = filter_signals.do_high_pass_filter(vib_sig, low_cut)
    filtered_raw_vib.append(flitered_vib_sig)
    print(f'Filtered {i+1} / {vib_signal_size} signals', end='\r')
filtered_raw_vib = np.asarray(filtered_raw_vib)
# Out:
# Filtered 410 / 410 signals

# %% [markdown]
# ### Plot FFT of raw and filtered raw for verification

# %%
i = 204
plotting_methods.plot_fft(times[i], vib_signal[i], avg_power=avg_power[i], avg_rpm=avg_rpm[i], interval_num=i)
# Out:
# T: 3.9062500000019984e-05
# Sampling f: 25600.097750373247
# f: [0.00000000e+00 9.76566225e-02 1.95313245e-01 ... 1.27997559e+04
#  1.27998535e+04 1.27999512e+04]

# %%
# %autoreload
import plotting_methods
# Out:
# ROOT /Users/mortenolsenosvik/Documents/NTNU/Master/master-thesis/src
# /Users/mortenolsenosvik/Documents/NTNU/Master/master-thesis/src

# %%
i = 1
plotting_methods.plot_fft(times[i], filtered_raw_vib[i], avg_power=avg_power[i], avg_rpm=avg_rpm[i], interval_num=i)

# %% [markdown]
# #### Save filtered, raw vibration signal to CSV

# %%
'''
path = '/Volumes/OsvikExtra/signal_data/raw_filtered_2000Hz/gearbox/wt01/';
list_size = len(filtered_raw_vib)
for i, vib_sig in enumerate(filtered_raw_vib):
    np.savetxt(f'{path}filtered_raw_{i}.csv', vib_sig, delimiter=',')
    print(f'Saved {i+1} / {list_size} files', end='\r')
'''
# Out:
# Saved 410 / 410 files

# %% [markdown]
# ### Filter out the first 6000Hz

# %%
low_cut = 6000
filtered_raw_vib_6000 = []
vib_signal_size = len(vib_signal)

for i, vib_sig in enumerate(vib_signal):
    flitered_vib_sig = filter_signals.do_high_pass_filter(vib_sig, low_cut)
    filtered_raw_vib_6000.append(flitered_vib_sig)
    print(f'Filtered {i+1} / {vib_signal_size} signals', end='\r')
filtered_raw_vib_6000 = np.asarray(filtered_raw_vib_6000)
# Out:
# Filtered 410 / 410 signals

# %% [markdown]
# ### Plot FFT of raw and filtered raw for verification

# %%
i = 1
plotting_methods.plot_fft(times[i], vib_signal[i], avg_power=avg_power[i], avg_rpm=avg_rpm[i], interval_num=i)

# %%
plotting_methods.plot_fft(times[i], filtered_raw_vib_6000[i], avg_power=avg_power[i], avg_rpm=avg_rpm[i], interval_num=i)

# %% [markdown]
# #### Save filtered, raw vibration signal to CSV

# %%
'''
path = '/Volumes/OsvikExtra/signal_data/raw_filtered_6000Hz/gearbox/wt01/';
list_size = len(filtered_raw_vib_6000)
for i, vib_sig in enumerate(filtered_raw_vib_6000):
    np.savetxt(f'{path}filtered_raw_6000_{i}.csv', vib_sig, delimiter=',')
    print(f'Saved {i+1} / {list_size} files', end='\r')
'''
# Out:
# "\npath = '/Volumes/OsvikExtra/signal_data/raw_filtered_6000Hz/gearbox/wt01/';\nlist_size = len(filtered_raw_vib_6000)\nfor i, vib_sig in enumerate(filtered_raw_vib_6000):\n    np.savetxt(f'{path}filtered_raw_6000_{i}.csv', vib_sig, delimiter=',')\n    print(f'Saved {i+1} / {list_size} files', end='\r')\n"

# %% [markdown]
# ## 2. Resampled signal

# %%
# Linear Interpolation

time = times[0]
resampled_vib_signal = []
resampled_time_signal = []

for i, vib_sig in enumerate(vib_signal):
    resampled_round, resampled_y, resampled_time = resample_signals.do_linear_resampling(
        time, 
        vib_sig, 
        peak_array[i],
        number_of_resample_points=1500
    )
    
    resampled_time_signal.append(resampled_time)
    resampled_vib_signal.append(resampled_y)
    print(f'Resampled {i+1} / {vib_signal_size} signals', end='\r')
# Out:
# Resampled 410 / 410 signals

# %%
i = 203
plotting_methods.plot_fft(resampled_time_signal[i], resampled_vib_signal[i], avg_power=avg_power[i], avg_rpm=avg_rpm[i], interval_num=i)
# Out:
# T: 2.6189334556392385e-05
# Sampling f: 37500.14318902331
# f: [0.00000000e+00 9.94364115e-02 1.98872823e-01 ... 1.90914927e+04
#  1.90915921e+04 1.90916916e+04]

# %% [markdown]
# ### 2.5 Filter out the first 2000 Hz

# %%
low_cut = 2000
filtered_resampled_vib = []
resampled_vib_signal_size = len(resampled_vib_signal)

skip = 0
for i, vib_sig in enumerate(resampled_vib_signal):
    if len(vib_sig) < 100000:
        filtered_resampled_vib.append(vib_sig)
        skip +=1
        continue
    flitered_vib_sig = filter_signals.do_high_pass_filter(vib_sig, low_cut)
    filtered_resampled_vib.append(flitered_vib_sig)
    print(f'Filtered {i+1} / {resampled_vib_signal_size} resampled signals', end='\r')
# Out:
# Filtered 410 / 410 resampled signals

# %%
i = 2
plotting_methods.plot_fft(resampled_time_signal[i], filtered_resampled_vib[i], avg_power=avg_power[i], avg_rpm=avg_rpm[i], interval_num=i)
# Out:
# T: 2.7127459973352863e-05
# Sampling f: 36621.233583030575
# f: [0.00000000e+00 9.83016390e-02 1.96603278e-01 ... 1.84312624e+04
#  1.84313607e+04 1.84314590e+04]

# %% [markdown]
# ### Save filtered resampled vibration signal to CSV

# %%
path = '/Volumes/OsvikExtra/signal_data/resampled_filtered_2000Hz/gearbox/wt01/';
list_size = len(filtered_resampled_vib)
for i, vib_sig in enumerate(filtered_resampled_vib):
    time_and_vib = np.array([resampled_time_signal[i], vib_sig])
    time_and_vib_pd = pd.DataFrame(time_and_vib.T, columns=['Time', 'VibrationSignal'])
    time_and_vib_pd.to_csv(f'{path}filtered_resampled_{i}.csv', sep=',', header=time_and_vib_pd.columns)
    print(f'Saved {i+1} / {list_size} files', end='\r')
# Out:
# Saved 410 / 410 files

# %% [markdown]
# ## 3. Filtered signal with optimal bandpass based on SK

# %%
# Read kurtogram data
fc_and_bw_path = '/Volumes/OsvikExtra/signal_data/resampled_filtered_2000Hz/gearbox/wt01/center_frequencies_&_bandwidth/fc_and_bw_data.csv';
frequencies_path = '/Volumes/OsvikExtra/signal_data/resampled_filtered_2000Hz/gearbox/wt01/center_frequencies_&_bandwidth/frequencies.csv';
file_names_path = '/Volumes/OsvikExtra/signal_data/resampled_filtered_2000Hz/gearbox/wt01/center_frequencies_&_bandwidth/file_name.txt';

fc_and_bw = pd.read_csv(fc_and_bw_path)
frequencies = pd.read_csv(frequencies_path)
file_names = pd.read_csv(file_names_path, header=None)

frequencies_numpy = np.asarray(frequencies).T
frequencies = pd.DataFrame(frequencies_numpy, columns= frequencies_numpy[0])
frequencies = frequencies.drop(frequencies.index[0]).reset_index(drop=True)
fc_and_bw
# Out:
#                            File   Frequencies   Bandwidths
# 0      filtered_resampled_0.csv  10376.016144  4150.406458
# 1      filtered_resampled_1.csv  12771.655165   567.629118
# 2     filtered_resampled_10.csv  12720.156556   565.340291
# 3    filtered_resampled_100.csv  12731.600691   286.103386
# 4    filtered_resampled_101.csv  12757.349996   280.381319
# 5    filtered_resampled_102.csv  13090.946544    70.953640
# 6    filtered_resampled_103.csv  12792.254609   370.789989
# 7    filtered_resampled_104.csv  12949.611472    69.809226
# 8    filtered_resampled_105.csv  12830.401727   382.997066
# 9    filtered_resampled_106.csv  12651.491743   460.054245
# 10   filtered_resampled_107.csv  12779.284589   381.471182
# 11   filtered_resampled_108.csv  12830.401727   382.997066
# 12   filtered_resampled_109.csv  12830.401727   382.997066
# 13    filtered_resampled_11.csv  12817.431707   341.798179
# 14   filtered_resampled_110.csv   9948.768420  3979.507368
# 15   filtered_resampled_111.csv  12833.453497   288.392213
# 16   filtered_resampled_112.csv  12728.167451   379.945297
# 17   filtered_resampled_113.csv  13084.080063    78.583063
# 18   filtered_resampled_114.csv  12771.655165   567.629118
# 19   filtered_resampled_115.csv  12729.693335   358.582911
# 20   filtered_resampled_116.csv  12739.611586   369.264104
# 21   filtered_resampled_117.csv  13033.868919    71.811950
# 22   filtered_resampled_118.csv  12779.284589   381.471182
# 23   filtered_resampled_119.csv  12527.895080   611.116833
# 24    filtered_resampled_12.csv  12830.401727   382.997066
# 25   filtered_resampled_120.csv  13072.492876    71.239743
# 26   filtered_resampled_121.csv  12720.156556   565.340291
# 27   filtered_resampled_122.csv  12729.311864   519.563750
# 28   filtered_resampled_123.csv  12097.595587    70.953640
# 29   filtered_resampled_124.csv  12966.062416    69.523123
# ..                          ...           ...          ...
# 394   filtered_resampled_72.csv  12426.900585    68.092606
# 395   filtered_resampled_73.csv  10314.980755  4125.992302
# 396   filtered_resampled_74.csv  12779.284589   381.471182
# 397   filtered_resampled_75.csv  13729.529303    98.419565
# 398   filtered_resampled_76.csv  12757.349996   280.381319
# 399   filtered_resampled_77.csv  13513.235143    73.242467
# 400   filtered_resampled_78.csv  12528.324235    75.245191
# 401   filtered_resampled_79.csv  12884.379900   289.536627
# 402    filtered_resampled_8.csv  12833.453497   288.392213
# 403   filtered_resampled_80.csv  12830.401727   382.997066
# 404   filtered_resampled_81.csv  12720.156556   565.340291
# 405   filtered_resampled_82.csv  12792.254609   370.789989
# 406   filtered_resampled_83.csv  12744.189240   292.969868
# 407   filtered_resampled_84.csv  13137.724448    72.384157
# 408   filtered_resampled_85.csv  13407.662993    72.670260
# 409   filtered_resampled_86.csv  11474.653147  4589.861259
# 410   filtered_resampled_87.csv  10070.839198  4028.335679
# 411   filtered_resampled_88.csv  12779.284589   381.471182
# 412   filtered_resampled_89.csv  13085.796683    72.098053
# 413    filtered_resampled_9.csv  12689.257390   769.045902
# 414   filtered_resampled_90.csv  13428.691592    71.239743
# 415   filtered_resampled_91.csv  12747.622481   542.452020
# 416   filtered_resampled_92.csv  12305.306646    96.512209
# 417   filtered_resampled_93.csv  12913.562445   283.814559
# 418   filtered_resampled_94.csv  12693.835044   540.163193
# 419   filtered_resampled_95.csv  12739.611586   772.097672
# 420   filtered_resampled_96.csv  11413.617758  4565.447103
# 421   filtered_resampled_97.csv  12881.518866   384.522951
# 422   filtered_resampled_98.csv  13278.630366    93.841911
# 423   filtered_resampled_99.csv  10803.263867  4321.305547
#
# [424 rows x 3 columns]

# %%
kurt_path = '/Volumes/OsvikExtra/signal_data/resampled_filtered_2000Hz/gearbox/wt01/kurtograms/';
kurt_file = f'{kurt_path}kgram_filtered_resampled_206.csv'
kurtogram = pd.read_csv(kurt_file, header=None)

# %%
plotting_methods.plot_kurtogram(kurtogram, frequencies['filtered_resampled_206.csv'])

# %% [markdown]
# ## 4. Demodulasation using EEMD signals

# %%
from PyEMD import EEMD
import numpy as np
import pylab as plt
# Define signal
S = vib_signal[0][0:10000]
t = times[0][0:10000]

# Assign EEMD to `eemd` variable
eemd = EEMD()
# Say we want detect extrema using parabolic method
emd = eemd.EMD
emd.extrema_detection="parabol"
# Execute EEMD on S
eIMFs = eemd.eemd(S, t)
nIMFs = eIMFs.shape[0]
# Plot results
plt.figure(figsize=(12,9))
plt.subplot(nIMFs+1, 1, 1)
plt.plot(t, S, 'r')

# %%
envelope_emd.eemd('WT01',1,'gearbox',vib_signal[0][0:10000],times[0][0:10000],True)

# %% [markdown]
# ## 5. Selecting IMF: Correlation coefficient

# %% [markdown]
# ## 6. Envelope spectral analysis

# %% [markdown]
# ## 7. Frequency study (fault characteristics), fault development
